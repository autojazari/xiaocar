# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
colors
# Out:
# array([ 0.15257319,  0.32675594,  0.70235737,  0.42883836,  0.10978675,
#         0.07311125,  0.43776225,  0.64265027,  0.70458281,  0.85072962,
#         0.6179656 ,  0.52688877,  0.2031346 ,  0.87306085,  0.29047195,
#         0.56625643,  0.55570612,  0.85241914,  0.77716161,  0.17578371,
#         0.58251351,  0.61528107,  0.66674326,  0.95881056,  0.0847982 ,
#         0.79120079,  0.75445026,  0.78203242,  0.8945496 ,  0.77827874,
#         0.70920802,  0.99226127,  0.99259625,  0.34472742,  0.3217573 ,
#         0.10873445,  0.59572663,  0.71316757,  0.23700756,  0.09850851,
#         0.86716362,  0.19814591,  0.5805117 ,  0.03573859,  0.92634597,
#         0.67044843,  0.54173847,  0.0374643 ,  0.33579367,  0.10697453])

# %%
filenames = glob.glob("../data/*.jpg")

x = []
y = []
images = []

for filename in filenames:
    # 148701337247041-0.773193359375-0.773193359375
    
    filename = filename.replace('.jpg', '')
    
    parts = filename.split('-')
    
    if float(parts[1]) == 0. or float(parts[2]) == 0.:
        continue
    
    
    x.append(parts[1])
    y.append(parts[2])

# %%
N = len(x)
colors = np.array(['b', 'r'])
area = np.pi * (15 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, c=colors, alpha=0.5)
plt.figure(figsize=(15,15))
plt.show()

# %%
colors
# Out:
# array([ 0.15257319,  0.32675594])

# %%
b =
